# %% [markdown]
# ### Question 1: List (Order and Duplicates)
#
# You are given a list of daily sales amounts:
#
# ```python
# sales = [1200, 1500, 1200, 1800, 1500]
# ```
#
# Tasks:
# 1. Print the total sales
# 2. Print the highest sale
# 3. Print how many times `1200` appears

# %%
# write your code here
sale=[1200,1500,1200,1800,1500]
total_sale=sum(sale)
hight_value=max(sale)
appears=sale.count(1200)
final_resulte=total_sale,hight_value,appears
print(final_resulte)
# Out:
# (7200, 1800, 2)

# %% [markdown]
# ### Question 2: Tuple (Fixed Data)
#
# You are given a tuple that stores a student’s basic information:
#
# ```python
# student = ("Aman", 21, "Delhi")
# ```
#
# Tasks:
# 1. Print the student’s name
# 2. Print the student’s age
# 3. Try to update the age and observe what happens

# %%
# write your code here
student=("aman",21,"delhi")
name=student[0]
age=student[1]
final_resulte=name,age
print(final_resulte)
age=student[1]=22
print(final_resulte)
# Out:
# ('aman', 21)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1310865174.py in <cell line: 0>()
#       5 final_resulte=name,age
#       6 print(final_resulte)
# ----> 7 age=student[1]=22
#       8 print(final_resulte)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Question 3: Set (Uniqueness)
#
# You are given two lists of students who attended two different workshops:
#
# ```python
# day1 = ["Rahul", "Aman", "Neha", "Rahul"]
# day2 = ["Neha", "Aman", "Sita"]
# ```
#
# Tasks:
# 1. Convert both lists into sets
# 2. Print students who attended both days
# 3. Print students who attended only Day 1

# %%
# write your code here
day1=["rahul","aman","neha","rahul"]
day2=["neha","aman","sita"]
day1=set(day1)
day2=set(day2)
final=day1,day2
print(final)
bhot_day=day1.intersection(day2)
print(bhot_day)
only_day1=day1.difference(day2)
print(only_day1)
# Out:
# ({'neha', 'aman', 'rahul'}, {'neha', 'sita', 'aman'})
# {'neha', 'aman'}
# {'rahul'}

# %% [markdown]
# ### Question 4: Dictionary (Key-Value Mapping)
#
# You are given marks of students in a subject:
#
# ```python
# marks = {
#     "Rahul": 85,
#     "Aman": 90,
#     "Neha": 78
# }
# ```
#
# Tasks:
# 1. Print marks of "Aman"
# 2. Add marks for "Sita" = 88
# 3. Update "Neha" marks to 80
# 4. Print all student names and their marks using a loop

# %%
# write your code here
marks={
    "rahul":85,
    "aman":90,
    "neha":78,

}
print(marks["aman"])
marks["sita"]=88
print(marks)
marks["neha"]=80
print(marks)
for name in marks:
  print(name,marks[name])
# Out:
# 90
# {'rahul': 85, 'aman': 90, 'neha': 78, 'sita': 88}
# {'rahul': 85, 'aman': 90, 'neha': 80, 'sita': 88}
# rahul 85
# aman 90
# neha 80
# sita 88

# %% [markdown]
# ### Question 5: Mixed Data Structures (Real-Life Scenario)
#
# You are given a list of orders:
#
# ```python
# orders = ["apple", "banana", "apple", "orange", "banana", "apple"]
# ```
#
# Tasks:
# 1. Find all unique products
# 2. Create a dictionary that stores product and its count
# 3. Print each product and its count

# %%
# write your code here
# dobut
orders=["apple","banana","apple","orange","banana","apple"]
ordersb=set(orders)
print(ordersb)
a={}

for i in orders:
  if i in a:
    a[i]+=1
  else:
    a[i]=1

    for i in a:
        print(i,a[i])
# Out:
# {'apple', 'banana', 'orange'}
# apple 1
# apple 1
# banana 1
# apple 2
# banana 1
# orange 1
