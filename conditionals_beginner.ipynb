# %% [markdown]
# # Conditionals in Python (Beginner Level)
#
# This notebook covers:
# - What are conditionals?
# - if, elif, else
# - Comparison operators
# - Simple examples
# - 10 beginner practice questions

# %% [markdown]
# ## 1. What Are Conditionals?
# Conditionals help Python make decisions based on conditions.

# %% [markdown]
# ## 2. Basic `if` Example

# %%
age = 20
if age >= 18:
    print("Adult")
# Out:
# Adult

# %% [markdown]
# ## 3. `if` and `else` Example

# %%
age = 15
if age >= 18:
    print("Adult")
else:
    print("Minor")
# Out:
# Minor

# %% [markdown]
# ## 4. `elif` Example

# %%
marks = 72
if marks >= 90:
    print("A Grade")
elif marks >= 75:
    print("B Grade")
else:

    print("C Grade")
# Out:
# C Grade

# %% [markdown]
# ## 5. Comparison Operators

# %% [markdown]
# | Operator | Meaning |
# |---------|---------|
# | == | equal to |
# | != | not equal to |
# | > | greater than |
# | < | less than |
# | >= | greater than or equal |
# | <= | less than or equal |

# %% [markdown]
# ## 6. Simple Examples

# %%
num = 6
if num % 2 == 0:
    print("Even")
else:
    print("Odd")

# %%
temp = 40
if temp > 35:
    print("It's hot")
else:
    print("Normal weather")

# %% [markdown]
# # Practice Questions

# %% [markdown]
# Given:
#
# ### bmi = 27
#
#
# Use conditions:
#
# BMI < 18.5 → "Underweight"
#
# BMI < 25 → "Normal"
#
# Else → "Overweight"

# %%
#Answer here
name=input(" enter your name: ")
address=input("enter your address:")
bmi=float(input("enter your bmi:"))
print("n/___result___")

if bmi <18:
  print("underweight" )
elif bmi <25:
  print("normal")
else:
  print("overweight")
# Out:
#  enter your name: akash
# enter your address:faeidabad
# enter your bmi:25
# n/___result___
# overweight

# %%
# Out:
# normal

# %% [markdown]
# ## Q. Electricity Bill Alert

# %% [markdown]
# ### units = 310
#
#
# Print:
#
# “Normal Usage” if units <= 200
#
# “High Usage” if units <= 300
#
# “Very High Usage” otherwise

# %%
#answer here
name=input("entre your name: ")
address=input("entre your address: ")
unit=int(input("entre your unit:"))
print("\n--- Usage Result ---")


if unit<=200:
  print("normal_usage")

elif unit<=300:
  print("high_usage")

else:
  print("very_high_usage")
# Out:
# entre your name: aaksh
# entre your address: faridabad
# entre your unit:500
#
# --- Usage Result ---
# very_high_usage

# %% [markdown]
# Smartphone Battery Checker

# %% [markdown]
# Given:
#
# battery = 12
#
#
# Print:
#
# “Battery Low” if battery < 20
#
# “Battery Medium” if battery < 80
#
# “Battery Full” otherwise

# %%
name=input("entre your name: ")
phone_name=input("entre your PHONE NAME: ")
battery=int(input("entre your unit:"))
print("\n--- Usage Result ---")
if battery<20:
  print("battery low")

elif battery<80:
  print(" battery medium")

else:
  print("battery full")
# Out:
# entre your name: kajal
# entre your PHONE NAME: realme
# entre your unit:50
#
# --- Usage Result ---
#  battery medium
